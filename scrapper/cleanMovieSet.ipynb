# %%
import pandas as pd


df = pd.read_csv("moviesdata.csv")

# Dropping 'url' and 'salles_premiere_semaine' columns
movies_data_cleaned = df.drop(['url'], axis=1)

# Keeping rows where both 'acteurs' and 'budget' are not null to avoid incomplete data
movies_data_cleaned = movies_data_cleaned.dropna(subset=['acteurs', 'budget'])

#Dropping duplicate rows based on all columns to ensure unique movie entries
movies_data_cleaned = movies_data_cleaned.drop_duplicates()

movies_data_cleaned.head()
# Out:
#                                               acteurs         budget  \
# 15  \r\n                            Robert Downey ...  220 000 000 $
# 17  \r\n                            Robert Downey ...  220 000 000 $
# 20  \r\n                            Antonio Bander...  160 000 000 $
# 21  \r\n                            Steve Carell,\...   75 000 000 $
# 28  \r\n                            Milla Jovovich...   75 200 000 €
#
#        compositeur          date                                      date_US  \
# 15  Alan Silvestri    25/04/2012                                          NaN
# 17  Alan Silvestri    25/04/2012  \r\n                             04/05/2012
# 20             NaN    13/06/2007                                          NaN
# 21             NaN    05/07/2017                                          NaN
# 28      Eric Serra    07/05/1997                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#    entrees_premiere_semaine  franchise            genre        pays  \
# 15                2 041 362  Franchise        Comicbook  Etats-Unis
# 17                2 041 362  Franchise        Comicbook  Etats-Unis
# 20                1 751 471  Franchise        Animation  Etats-Unis
# 21                1 756 100  Franchise        Animation  Etats-Unis
# 28                1 813 448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur                                        realisateur  \
# 15  Kevin Feige  \r\n                                    Joss W...
# 17  Kevin Feige  \r\n                                    Joss W...
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 28          NaN  \r\n                                    Luc Be...
#
#    recette_premier_wk_US remake salles_premiere_semaine  \
# 15                   NaN    NaN                     668
# 17        207 438 708 $     NaN                     668
# 20                   NaN    NaN                     850
# 21                   NaN    NaN                     877
# 28                   NaN    NaN                     527
#
#                                       studio  \
# 15  \r\n                Walt Disney Pictures
# 17  \r\n                Walt Disney Pictures
# 20             \r\n                Paramount
# 21             \r\n                Universal
# 28                  \r\n                GBVI
#
#                                                 titre
# 15  \r\n                            Marvel's The A...
# 17  \r\n                            Marvel's The A...
# 20  \r\n                            Shrek Le Trois...
# 21  \r\n                            Moi, Moche et ...
# 28  \r\n                            Le Cinquième é...

# %%
movies_data_cleaned.shape
# Out:
# (7345, 19)

# %% [markdown]
# ### Titre

# %%
for index, value in movies_data_cleaned['titre'].items():
    if isinstance(value,str):
        value = value.replace('\r\n','')
        value = value.strip()
        movies_data_cleaned.at[index, 'titre'] = value

# %% [markdown]
# ### Acteurs

# %%
movies_data_cleaned['acteurs'] = movies_data_cleaned['acteurs'].str.strip().replace(r"\r\n", "", regex=True).replace(r"\s+", " ", regex=True) 

movies_data_cleaned.head()
# Out:
#                                               acteurs         budget  \
# 15  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 17  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 20  Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160 000 000 $
# 21            Steve Carell, Gad Elmaleh, Kristen Wiig   75 000 000 $
# 28  Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75 200 000 €
#
#        compositeur          date                                      date_US  \
# 15  Alan Silvestri    25/04/2012                                          NaN
# 17  Alan Silvestri    25/04/2012  \r\n                             04/05/2012
# 20             NaN    13/06/2007                                          NaN
# 21             NaN    05/07/2017                                          NaN
# 28      Eric Serra    07/05/1997                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#    entrees_premiere_semaine  franchise            genre        pays  \
# 15                2 041 362  Franchise        Comicbook  Etats-Unis
# 17                2 041 362  Franchise        Comicbook  Etats-Unis
# 20                1 751 471  Franchise        Animation  Etats-Unis
# 21                1 756 100  Franchise        Animation  Etats-Unis
# 28                1 813 448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur                                        realisateur  \
# 15  Kevin Feige  \r\n                                    Joss W...
# 17  Kevin Feige  \r\n                                    Joss W...
# 20          NaN                                                NaN
# 21          NaN                                                NaN
# 28          NaN  \r\n                                    Luc Be...
#
#    recette_premier_wk_US remake salles_premiere_semaine  \
# 15                   NaN    NaN                     668
# 17        207 438 708 $     NaN                     668
# 20                   NaN    NaN                     850
# 21                   NaN    NaN                     877
# 28                   NaN    NaN                     527
#
#                                       studio                    titre
# 15  \r\n                Walt Disney Pictures    Marvel's The Avengers
# 17  \r\n                Walt Disney Pictures    Marvel's The Avengers
# 20             \r\n                Paramount       Shrek Le Troisième
# 21             \r\n                Universal  Moi, Moche et Méchant 3
# 28                  \r\n                GBVI     Le Cinquième élément

# %% [markdown]
# ### Studio

# %%
for index, value in movies_data_cleaned['studio'].items():
    if isinstance(value,str):
        value = value.replace('\r\n','')
        value = value.strip()
        movies_data_cleaned.at[index, 'studio'] = value

# %% [markdown]
# ### Réalisateur

# %%
for index, value in movies_data_cleaned['realisateur'].items():
    if isinstance(value,str):
        value = value.replace('\r\n','')
        value = value.replace('-','')
        value = value.strip()
        movies_data_cleaned.at[index, 'realisateur'] = value

movies_data_cleaned.head()
# Out:
#                                               acteurs         budget  \
# 15  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 17  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 20  Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160 000 000 $
# 21            Steve Carell, Gad Elmaleh, Kristen Wiig   75 000 000 $
# 28  Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75 200 000 €
#
#        compositeur          date                                      date_US  \
# 15  Alan Silvestri    25/04/2012                                          NaN
# 17  Alan Silvestri    25/04/2012  \r\n                             04/05/2012
# 20             NaN    13/06/2007                                          NaN
# 21             NaN    05/07/2017                                          NaN
# 28      Eric Serra    07/05/1997                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#    entrees_premiere_semaine  franchise            genre        pays  \
# 15                2 041 362  Franchise        Comicbook  Etats-Unis
# 17                2 041 362  Franchise        Comicbook  Etats-Unis
# 20                1 751 471  Franchise        Animation  Etats-Unis
# 21                1 756 100  Franchise        Animation  Etats-Unis
# 28                1 813 448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur  realisateur recette_premier_wk_US remake  \
# 15  Kevin Feige  Joss Whedon                   NaN    NaN
# 17  Kevin Feige  Joss Whedon        207 438 708 $     NaN
# 20          NaN          NaN                   NaN    NaN
# 21          NaN          NaN                   NaN    NaN
# 28          NaN   Luc Besson                   NaN    NaN
#
#    salles_premiere_semaine                studio                    titre
# 15                     668  Walt Disney Pictures    Marvel's The Avengers
# 17                     668  Walt Disney Pictures    Marvel's The Avengers
# 20                     850             Paramount       Shrek Le Troisième
# 21                     877             Universal  Moi, Moche et Méchant 3
# 28                     527                  GBVI     Le Cinquième élément

# %% [markdown]
# ### Date

# %%
movies_data_cleaned['date'] = movies_data_cleaned['date'].str.strip()
movies_data_cleaned['date'] = pd.to_datetime(movies_data_cleaned['date'], format='%d/%m/%Y')

movies_data_cleaned.head()
# Out:
#                                               acteurs         budget  \
# 15  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 17  Robert Downey Jr, Scarlett Johansson, Chris He...  220 000 000 $
# 20  Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160 000 000 $
# 21            Steve Carell, Gad Elmaleh, Kristen Wiig   75 000 000 $
# 28  Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75 200 000 €
#
#        compositeur       date                                      date_US  \
# 15  Alan Silvestri 2012-04-25                                          NaN
# 17  Alan Silvestri 2012-04-25  \r\n                             04/05/2012
# 20             NaN 2007-06-13                                          NaN
# 21             NaN 2017-07-05                                          NaN
# 28      Eric Serra 1997-05-07                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#    entrees_premiere_semaine  franchise            genre        pays  \
# 15                2 041 362  Franchise        Comicbook  Etats-Unis
# 17                2 041 362  Franchise        Comicbook  Etats-Unis
# 20                1 751 471  Franchise        Animation  Etats-Unis
# 21                1 756 100  Franchise        Animation  Etats-Unis
# 28                1 813 448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur  realisateur recette_premier_wk_US remake  \
# 15  Kevin Feige  Joss Whedon                   NaN    NaN
# 17  Kevin Feige  Joss Whedon        207 438 708 $     NaN
# 20          NaN          NaN                   NaN    NaN
# 21          NaN          NaN                   NaN    NaN
# 28          NaN   Luc Besson                   NaN    NaN
#
#    salles_premiere_semaine                studio                    titre
# 15                     668  Walt Disney Pictures    Marvel's The Avengers
# 17                     668  Walt Disney Pictures    Marvel's The Avengers
# 20                     850             Paramount       Shrek Le Troisième
# 21                     877             Universal  Moi, Moche et Méchant 3
# 28                     527                  GBVI     Le Cinquième élément

# %% [markdown]
# ### Budget

# %%
movies_data_cleaned['budget'] = movies_data_cleaned['budget'].str.replace('[\$,€]', '', regex=True).str.replace(' ', '').str.replace('?', '')
movies_data_cleaned['budget'] = pd.to_numeric(movies_data_cleaned['budget'], errors='coerce').fillna(0).astype(int)

movies_data_cleaned.head()
# Out:
#                                               acteurs     budget  \
# 15  Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 17  Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 20  Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160000000
# 21            Steve Carell, Gad Elmaleh, Kristen Wiig   75000000
# 28  Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75200000
#
#        compositeur       date                                      date_US  \
# 15  Alan Silvestri 2012-04-25                                          NaN
# 17  Alan Silvestri 2012-04-25  \r\n                             04/05/2012
# 20             NaN 2007-06-13                                          NaN
# 21             NaN 2017-07-05                                          NaN
# 28      Eric Serra 1997-05-07                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#    entrees_premiere_semaine  franchise            genre        pays  \
# 15                2 041 362  Franchise        Comicbook  Etats-Unis
# 17                2 041 362  Franchise        Comicbook  Etats-Unis
# 20                1 751 471  Franchise        Animation  Etats-Unis
# 21                1 756 100  Franchise        Animation  Etats-Unis
# 28                1 813 448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur  realisateur recette_premier_wk_US remake  \
# 15  Kevin Feige  Joss Whedon                   NaN    NaN
# 17  Kevin Feige  Joss Whedon        207 438 708 $     NaN
# 20          NaN          NaN                   NaN    NaN
# 21          NaN          NaN                   NaN    NaN
# 28          NaN   Luc Besson                   NaN    NaN
#
#    salles_premiere_semaine                studio                    titre
# 15                     668  Walt Disney Pictures    Marvel's The Avengers
# 17                     668  Walt Disney Pictures    Marvel's The Avengers
# 20                     850             Paramount       Shrek Le Troisième
# 21                     877             Universal  Moi, Moche et Méchant 3
# 28                     527                  GBVI     Le Cinquième élément

# %% [markdown]
# ### Nombre d'entrées

# %%
movies_data_cleaned['entrees_premiere_semaine'] = movies_data_cleaned['entrees_premiere_semaine'].str.replace(' ', '').astype(int) 

movies_data_cleaned.head()
# Out:
#                                               acteurs     budget  \
# 15  Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 17  Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 20  Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160000000
# 21            Steve Carell, Gad Elmaleh, Kristen Wiig   75000000
# 28  Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75200000
#
#        compositeur       date                                      date_US  \
# 15  Alan Silvestri 2012-04-25                                          NaN
# 17  Alan Silvestri 2012-04-25  \r\n                             04/05/2012
# 20             NaN 2007-06-13                                          NaN
# 21             NaN 2017-07-05                                          NaN
# 28      Eric Serra 1997-05-07                                          NaN
#
#                                                 duree  \
# 15  \r\n                                  2h 22min...
# 17  \r\n                                  2h 22min...
# 20  \r\n                                  1h 32min...
# 21  \r\n                                  1h 36min...
# 28  \r\n                                  2h 06min...
#
#     entrees_premiere_semaine  franchise            genre        pays  \
# 15                   2041362  Franchise        Comicbook  Etats-Unis
# 17                   2041362  Franchise        Comicbook  Etats-Unis
# 20                   1751471  Franchise        Animation  Etats-Unis
# 21                   1756100  Franchise        Animation  Etats-Unis
# 28                   1813448        NaN  Science Fiction      France
#
#            pegi_FR                                            pegi_US  \
# 15   Tous publics                                                 NaN
# 17   Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 20   Tous publics                                                 NaN
# 21   Tous publics                                                 NaN
# 28   Tous publics                                                 NaN
#
#      producteur  realisateur recette_premier_wk_US remake  \
# 15  Kevin Feige  Joss Whedon                   NaN    NaN
# 17  Kevin Feige  Joss Whedon        207 438 708 $     NaN
# 20          NaN          NaN                   NaN    NaN
# 21          NaN          NaN                   NaN    NaN
# 28          NaN   Luc Besson                   NaN    NaN
#
#    salles_premiere_semaine                studio                    titre
# 15                     668  Walt Disney Pictures    Marvel's The Avengers
# 17                     668  Walt Disney Pictures    Marvel's The Avengers
# 20                     850             Paramount       Shrek Le Troisième
# 21                     877             Universal  Moi, Moche et Méchant 3
# 28                     527                  GBVI     Le Cinquième élément

# %%
movies_data_cleaned
# Out:
#                                                  acteurs     budget  \
# 15     Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 17     Robert Downey Jr, Scarlett Johansson, Chris He...  220000000
# 20     Antonio Banderas, Alain Chabat, Cameron Diaz, ...  160000000
# 21               Steve Carell, Gad Elmaleh, Kristen Wiig   75000000
# 28     Milla Jovovich, Bruce Willis, Chris Tucker, Ma...   75200000
# ...                                                  ...        ...
# 19341                          Naomi Watts, Robin Wright   11908774
# 19353                                        Liam Neeson   28000000
# 19354                                         Mike Myers          0
# 19356                                          Tom Hardy   25000000
# 19358                                          Tom Hardy   25000000
#
#           compositeur       date                                      date_US  \
# 15     Alan Silvestri 2012-04-25                                          NaN
# 17     Alan Silvestri 2012-04-25  \r\n                             04/05/2012
# 20                NaN 2007-06-13                                          NaN
# 21                NaN 2017-07-05                                          NaN
# 28         Eric Serra 1997-05-07                                          NaN
# ...               ...        ...                                          ...
# 19341             NaN 2013-04-03  \r\n                             06/09/2013
# 19353             NaN 2014-10-15  \r\n                             19/09/2014
# 19354             NaN 1994-06-22  \r\n                             30/07/1993
# 19356             NaN 2016-01-20                                          NaN
# 19358             NaN 2016-01-20  \r\n                             20/11/2015
#
#                                                    duree  \
# 15     \r\n                                  2h 22min...
# 17     \r\n                                  2h 22min...
# 20     \r\n                                  1h 32min...
# 21     \r\n                                  1h 36min...
# 28     \r\n                                  2h 06min...
# ...                                                  ...
# 19341  \r\n                                  1h 51min...
# 19353  \r\n                                  1h 54min...
# 19354  \r\n                                  1h 50min...
# 19356  \r\n                                  2h 11min...
# 19358  \r\n                                  2h 11min...
#
#        entrees_premiere_semaine  franchise            genre             pays  \
# 15                      2041362  Franchise        Comicbook       Etats-Unis
# 17                      2041362  Franchise        Comicbook       Etats-Unis
# 20                      1751471  Franchise        Animation       Etats-Unis
# 21                      1756100  Franchise        Animation       Etats-Unis
# 28                      1813448        NaN  Science Fiction           France
# ...                         ...        ...              ...              ...
# 19341                    111058        NaN            Drame        Australie
# 19353                    110509        NaN         Thriller       Etats-Unis
# 19354                    110411        NaN          Comédie       Etats-Unis
# 19356                    110406        NaN         Thriller  Grande-Bretagne
# 19358                    110406        NaN         Thriller  Grande-Bretagne
#
#                     pegi_FR  \
# 15            Tous publics
# 17            Tous publics
# 20            Tous publics
# 21            Tous publics
# 28            Tous publics
# ...                     ...
# 19341         Tous publics
# 19353      Moins de 12 ans
# 19354  \r\n
# 19356      Moins de 12 ans
# 19358      Moins de 12 ans
#
#                                                  pegi_US   producteur  \
# 15                                                   NaN  Kevin Feige
# 17     <div class="bloc_infos_center tablesmall1">\r\...  Kevin Feige
# 20                                                   NaN          NaN
# 21                                                   NaN          NaN
# 28                                                   NaN          NaN
# ...                                                  ...          ...
# 19341  <div class="bloc_infos_center tablesmall1">\r\...          NaN
# 19353  <div class="bloc_infos_center tablesmall1">\r\...          NaN
# 19354  <div class="bloc_infos_center tablesmall1">\r\...          NaN
# 19356                                                NaN          NaN
# 19358  <div class="bloc_infos_center tablesmall1">\r\...          NaN
#
#          realisateur recette_premier_wk_US remake salles_premiere_semaine  \
# 15       Joss Whedon                   NaN    NaN                     668
# 17       Joss Whedon        207 438 708 $     NaN                     668
# 20               NaN                   NaN    NaN                     850
# 21               NaN                   NaN    NaN                     877
# 28        Luc Besson                   NaN    NaN                     527
# ...              ...                   ...    ...                     ...
# 19341  Anne Fontaine            125 000 $     NaN                     242
# 19353            NaN         12 758 780 $     NaN                       -
# 19354            NaN          3 466 930 $     NaN                      99
# 19356            NaN                   NaN    NaN                     223
# 19358            NaN             86 836 $     NaN                     223
#
#                      studio                          titre
# 15     Walt Disney Pictures          Marvel's The Avengers
# 17     Walt Disney Pictures          Marvel's The Avengers
# 20                Paramount             Shrek Le Troisième
# 21                Universal        Moi, Moche et Méchant 3
# 28                     GBVI           Le Cinquième élément
# ...                     ...                            ...
# 19341               Gaumont                Perfect Mothers
# 19353          Metropolitan        Balade entre les tombes
# 19354              Columbia  Quand Harriet découpe Charlie
# 19356           Studiocanal                  Legend (2016)
# 19358           Studiocanal                  Legend (2016)
#
# [7345 rows x 19 columns]

# %%
df_filtered = movies_data_cleaned.groupby('titre').filter(lambda x: len(x) > 1 and x['date_US'].notna().any())

df_us = df_filtered.groupby('titre').apply(lambda x: x if x['date_US'].notna().all() else x[x['date_US'].notna()]).reset_index(drop=True)

display(df_us)
# Out:
# /var/folders/f8/_srl45g93hb_f9bb62qtf1t80000gn/T/ipykernel_18469/2501897356.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_us = df_filtered_us.groupby('titre').apply(lambda x: x if x['date_US'].notna().all() else x[x['date_US'].notna()]).reset_index(drop=True)
#                                                 acteurs     budget  \
# 0                                          Alain Chabat   11378260
# 1                        Scarlett Johansson, Demi Moore   20000000
# 2                  Chris Evans, Anna Faris, Chris Pratt   20000000
# 3                           Drew Barrymore, Ben Stiller   40000000
# 4                                          John Goodman   15000000
# ...                                                 ...        ...
# 2813  Daniel Craig, Toni Collette, Jamie Lee Curtis,...   40000000
# 2814                                       Willem Dafoe          0
# 2815                                   Pascal Legitimus          0
# 2816                                     George Clooney  190000000
# 2817                     Jessica Chastain, James McAvoy   79000000
#
#      compositeur       date                                      date_US  \
# 0            NaN 2020-02-05  \r\n                             00/00/0000
# 1            NaN 2017-08-02  \r\n                             16/06/2017
# 2            NaN 2011-10-05  \r\n                             30/09/2011
# 3            NaN 2004-07-07  \r\n                             26/09/2003
# 4            NaN 2016-03-16  \r\n                             11/03/2016
# ...          ...        ...                                          ...
# 2813         NaN 2019-11-27  \r\n                             27/11/2019
# 2814         NaN 2023-11-01  \r\n                             17/03/2023
# 2815         NaN 2023-02-22  \r\n                             00/00/0000
# 2816         NaN 2015-05-20  \r\n                             22/05/2015
# 2817         NaN 2019-09-11  \r\n                             06/09/2019
#
#                                                   duree  \
# 0     \r\n                                  1h 38min...
# 1     \r\n                                  1h 41min...
# 2     \r\n                                  1h 48min...
# 3     \r\n                                  1h 37min...
# 4     \r\n                                  1h 45min...
# ...                                                 ...
# 2813  \r\n                                  2h 11min...
# 2814  \r\n                                  1h 45min...
# 2815  \r\n                                  1h 50min...
# 2816  \r\n                                  2h 10min...
# 2817  \r\n                                  2h 45min...
#
#       entrees_premiere_semaine  franchise               genre        pays  \
# 0                       112363        NaN             Comédie      France
# 1                        66666        NaN             Comédie  Etats-Unis
# 2                        95712        NaN             Comédie  Etats-Unis
# 3                       101217        NaN             Comédie  Etats-Unis
# 4                       262590        NaN            Thriller  Etats-Unis
# ...                        ...        ...                 ...         ...
# 2813                    283889        NaN            Thriller  Etats-Unis
# 2814                      2654        NaN               Drame       Grèce
# 2815                     67974        NaN  Comédie dramatique      France
# 2816                    418815        NaN     Science Fiction  Etats-Unis
# 2817                    635024  Franchise             Horreur  Etats-Unis
#
#                    pegi_FR                                            pegi_US  \
# 0            Tous publics   <div class="bloc_infos_center tablesmall1" ite...
# 1            Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 2            Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 3     \r\n                  <div class="bloc_infos_center tablesmall1">\r\...
# 4            Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# ...                    ...                                                ...
# 2813         Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 2814         Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 2815         Tous publics   <div class="bloc_infos_center tablesmall1" ite...
# 2816         Tous publics   <div class="bloc_infos_center tablesmall1">\r\...
# 2817      Moins de 12 ans   <div class="bloc_infos_center tablesmall1">\r\...
#
#        producteur    realisateur recette_premier_wk_US remake  \
# 0             NaN  Eric Lartigau                   NaN    NaN
# 1             NaN            NaN          8 004 283 $     NaN
# 2             NaN            NaN          5 421 669 $     NaN
# 3             NaN            NaN          4 617 128 $     NaN
# 4     J.J. Abrams            NaN         24 702 752 $     NaN
# ...           ...            ...                   ...    ...
# 2813          NaN   Rian Johnson         26 769 548 $     NaN
# 2814          NaN            NaN            510 110 $     NaN
# 2815          NaN            NaN                   NaN    NaN
# 2816          NaN      Brad Bird         33 028 165 $     NaN
# 2817          NaN            NaN         91 062 152 $     NaN
#
#      salles_premiere_semaine                studio                     titre
# 0                        387               Gaumont                 #Jesuislà
# 1                        145         Sony Pictures              #Pire soirée
# 2                        208      20th Century Fox                (S)ex List
# 3                        120      TFM Distribution           1 duplex pour 3
# 4                        277             Paramount       10 Cloverfield Lane
# ...                      ...                   ...                       ...
# 2813                     434          Metropolitan   À couteaux tirés (2019)
# 2814                     NaN                     -      À l'intérieur (2023)
# 2815                     225             Bac Films         À la belle étoile
# 2816                     551  Walt Disney Pictures  À la poursuite de demain
# 2817                     600          Warner Bros.             Ça Chapitre 2
#
# [2818 rows x 19 columns]
